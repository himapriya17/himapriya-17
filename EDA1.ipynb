# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("data_clean.csv")
print(data)
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
#dataframe atrributes
print(type(data))
print(data.shape)
print(data.size)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (158, 10)
# 1580

# %%
#drop duplicate column(temp c) and unamed column 
data1 = data.drop(['Unnamed: 0',"Temp C"], axis=1)
data1
# Out:
#      Ozone  Solar.R  Wind Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4     5    1  2010    67       S
# 1     36.0    118.0   8.0     5    2  2010    72       C
# 2     12.0    149.0  12.6     5    3  2010    74      PS
# 3     18.0    313.0  11.5     5    4  2010    62       S
# 4      NaN      NaN  14.3     5    5  2010    56       S
# ..     ...      ...   ...   ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4     5    1  2010    67       C
# 154   30.0    193.0   6.9     9   26  2010    70      PS
# 155    NaN    145.0  13.2     9   27  2010    77       S
# 156   14.0    191.0  14.3     9   28  2010    75       S
# 157   18.0    131.0   8.0     9   29  2010    76       C
#
# [158 rows x 8 columns]

# %%
#convert the month column data type to  float data type
data['Month']=pd.to_numeric(data['Month'],errors='coerce')
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Month    158 non-null    object
#  4   Day      158 non-null    int64
#  5   Year     158 non-null    int64
#  6   Temp     158 non-null    int64
#  7   Weather  155 non-null    object
# dtypes: float64(3), int64(3), object(2)
# memory usage: 10.0+ KB

# %%
#print all duplicated rows
data1[data1.duplicated(keep = False)]
# Out:
#      Ozone  Solar.R  Wind Month  Day  Year  Temp Weather
# 150   14.0    191.0  14.3     9   28  2010    75       S
# 156   14.0    191.0  14.3     9   28  2010    75       S

# %%
#drop duplicated rows
data1.drop_duplicates(keep='first', inplace = True)
data1
# Out:
#      Ozone  Solar.R  Wind Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4     5    1  2010    67       S
# 1     36.0    118.0   8.0     5    2  2010    72       C
# 2     12.0    149.0  12.6     5    3  2010    74      PS
# 3     18.0    313.0  11.5     5    4  2010    62       S
# 4      NaN      NaN  14.3     5    5  2010    56       S
# ..     ...      ...   ...   ...  ...   ...   ...     ...
# 152   20.0    223.0  11.5     9   30  2010    68       S
# 153   41.0    190.0   7.4     5    1  2010    67       C
# 154   30.0    193.0   6.9     9   26  2010    70      PS
# 155    NaN    145.0  13.2     9   27  2010    77       S
# 157   18.0    131.0   8.0     9   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
#rename the columns
#CHANGE COLUMN NAME(RENAME THE COLUMNS)
data1.rename({'Solar.R': 'Solar'}, axis=1, inplace = True)
data1
# Out:
#      Ozone  Solar  Wind Month  Day  Year  Temp Weather
# 0     41.0  190.0   7.4     5    1  2010    67       S
# 1     36.0  118.0   8.0     5    2  2010    72       C
# 2     12.0  149.0  12.6     5    3  2010    74      PS
# 3     18.0  313.0  11.5     5    4  2010    62       S
# 4      NaN    NaN  14.3     5    5  2010    56       S
# ..     ...    ...   ...   ...  ...   ...   ...     ...
# 152   20.0  223.0  11.5     9   30  2010    68       S
# 153   41.0  190.0   7.4     5    1  2010    67       C
# 154   30.0  193.0   6.9     9   26  2010    70      PS
# 155    NaN  145.0  13.2     9   27  2010    77       S
# 157   18.0  131.0   8.0     9   29  2010    76       C
#
# [157 rows x 8 columns]

# %%
#imput the missing values
#display the data1 info()
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 157 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    119 non-null    float64
#  1   Solar    150 non-null    float64
#  2   Wind     157 non-null    float64
#  3   Month    157 non-null    object
#  4   Day      157 non-null    int64
#  5   Year     157 non-null    int64
#  6   Temp     157 non-null    int64
#  7   Weather  154 non-null    object
# dtypes: float64(3), int64(3), object(2)
# memory usage: 11.0+ KB

# %%
#display data1 missing values count in each column using isnull().sum()
data1.isnull().sum()
# Out:
# Ozone      38
# Solar       7
# Wind        0
# Month       0
# Day         0
# Year        0
# Temp        0
# Weather     3
# dtype: int64

# %%
#viusalize dat1 missing values using heat map
cols = data1.columns
colors = ['black', 'blue']
sns.heatmap(data1[cols].isnull(),cmap=sns.color_palette(colors),cbar = True)
# Out:
# <Axes: >

# %%
#find the mean and median values of each
median_ozone = data1["Ozone"].median()
mean_ozone = data1["Ozone"].mean()
print("Median of Ozone: ", median_ozone)
print("Mean of Ozone: ", mean_ozone)
# Out:
# Median of Ozone:  31.0
# Mean of Ozone:  41.81512605042017

# %%
#replace the ozone missing values with median value
data1["Ozone"] = data1['Ozone'].fillna(median_ozone)
data1.isnull().sum()
# Out:
# Ozone      0
# Solar      7
# Wind       0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    3
# dtype: int64

# %%
#find the mode values of categorcial column(weather)
print(data1["Weather"].value_counts())
mode_weather = data1["Weather"].mode()[0]
print(mode_weather)
# Out:
# Weather
# S     58
# C     49
# PS    47
# Name: count, dtype: int64
# S

# %%
#impute missing values(replace nan with mode etc.) of "weather" using mh=fillnan()
data1["Weather"] = data1["Weather"].fillna(mode_weather)
data1.isnull().sum()
# Out:
# Ozone      0
# Solar      7
# Wind       0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    0
# dtype: int64

# %% [markdown]
# detection of outliers in the columns

# %%
#create a figure with two subplots, stacked vertically
fig, axes = plt.subplots(2, 1, figsize=(8,6),gridspec_kw={'height_ratios':[1,3]})
#plot the boxplot un the first (top) subplot
sns.boxplot(data=data1['Ozone'], ax=axes[0], color='orange',width=0.5, orient = 'h')
axes[0].set_title("Boxplot")
axes[0].set_xlabel("Ozone Levels")

sns.histplot(data1["Ozone"], kde=True, ax=axes[1], color='green', bins=30)
axes[1].set_title("Histogram with KDE")
axes[1].set_xlabel("Ozone Levels")
axes[1].set_ylabel("Frequency")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### observations
# 1 the ozone column has extreme values beyond 81 as seen from box plot
# 2the same is confirmed from the below right-skewed histogram

# %%
#create a figure for violin in plot
sns.violinplot(data=data1["Ozone"], color='purple')
plt.title("Violin Plot")
plt.show()

# %%
plt.figure(figsize=(7,8))
plt.boxplot(data1["Ozone"], vert = False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x181f65b5490>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x181f66523c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x181f6651c40>],
#  'medians': [<matplotlib.lines.Line2D at 0x181f6652930>],
#  'fliers': [<matplotlib.lines.Line2D at 0x181f6652bd0>],
#  'means': []}

# %%
plt.figure(figsize=(9,8))
boxplot_data = plt.boxplot(data1["Ozone"], vert=False)
[item.get_xdata() for item in boxplot_data['fliers']]
# Out:
# [array([115., 135.,  97.,  97.,  85., 108.,  82., 122.,  89., 110., 168.,
#         118.,  84.,  85.,  96.,  91.])]

# %%
### method 2
#using mu =/- 3*sigma limits(standard deviation method)
data1["Ozone"].describe()
# Out:
# count    157.000000
# mean      39.197452
# std       28.781992
# min        1.000000
# 25%       21.000000
# 50%       31.000000
# 75%       45.000000
# max      168.000000
# Name: Ozone, dtype: float64

# %%
mu = data1["Ozone"].describe()[1]
sigma = data1["Ozone"].describe()[2]

for x in data1["Ozone"]:
    if ((x < (mu - 3*sigma)) or (x > (mu + 3*sigma))):
        print(x)
# Out:
# 135.0
# 168.0
# C:\Users\rishi\AppData\Local\Temp\ipykernel_1888\3121128980.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   mu = data1["Ozone"].describe()[1]
# C:\Users\rishi\AppData\Local\Temp\ipykernel_1888\3121128980.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sigma = data1["Ozone"].describe()[2]

# %% [markdown]
# ### observations
# 1 it is observed that only two outliers are idetified
# 2 in box plot method more no.of ouliers are identified
# 3 this is becaause the assumption of normallyis not satsifed in this column

# %%
#Quantile-Quantile plot for detection of outliers
import scipy.stats as stats

# create q-q plot
plt.figure(figsize=(8,6))
stats.probplot(data1["Ozone"], dist="norm", plot=plt)
plt.title("Q-Q Plot for outlier Detection", fontsize=14)
plt.xlabel("Theoretical Quantiles", fontsize=12)
# Out:
# Text(0.5, 0, 'Theoretical Quantiles')

# %% [markdown]
# observations fro  Q-Q plot
# 1 the data does not follow normal distribution as the data points are deviationg sugnuficantly away from the red line
# 2 the data shows a right_skewed distribution and possible outliers

# %%
#Quantile-Quantile plot for detection of outliers
import scipy.stats as stats

# create q-q plot
plt.figure(figsize=(8,6))
stats.probplot(data1["Solar"], dist="norm", plot=plt)
plt.title("Q-Q Plot for outlier Detection", fontsize=14)
plt.xlabel("Theoretical Quantiles", fontsize=12)
# Out:
# Text(0.5, 0, 'Theoretical Quantiles')

# %%
# create  a figure for violin plot
sns.violinplot(data=data1["Ozone"], color='violet')
plt.title("Violin Plot")

#show the plot
plt.show()

# %%
sns.swarmplot(data=data1, x = "Weather", y = "Ozone", color="orange",palette="Set2",size=6)
# Out:
# C:\Users\rishi\AppData\Local\Temp\ipykernel_1888\1041019778.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(data=data1, x = "Weather", y = "Ozone", color="orange",palette="Set2",size=6)
# <Axes: xlabel='Weather', ylabel='Ozone'>

# %%
sns.stripplot(data=data1, x = "Weather", y = "Ozone",color="orange", palette="Set1", size=6, jitter = True)
# Out:
# C:\Users\rishi\AppData\Local\Temp\ipykernel_1888\489543265.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data=data1, x = "Weather", y = "Ozone",color="orange", palette="Set1", size=6, jitter = True)
# <Axes: xlabel='Weather', ylabel='Ozone'>

# %%
sns.kdeplot(data=data1["Ozone"], fill=True, color="purple")
sns.rugplot(data=data1["Ozone"], color="black")
# Out:
# <Axes: xlabel='Ozone', ylabel='Density'>

# %%
#category wise boxplot for ozone
sns.boxplot(data = data1, x = "Weather", y="Ozone")
# Out:
# <Axes: xlabel='Weather', ylabel='Ozone'>

# %%
#category wise boxplot for ozone
sns.boxplot(data = data1, y="Ozone")
# Out:
# <Axes: ylabel='Ozone'>

# %% [markdown]
# Correlation coefficient and pair plots

# %%
plt.scatter(data1["Wind"],data1["Temp"])

# %%
#Compute pearson correlation coefficient
#between wind speed amd temperature
data["Wind"].corr(data1["Temp"])
# Out:
# -0.44122806925588215

# %%
#read all numeric columns into a new table
data1_numeric = data1.iloc[:,[0,1,2,6]]
data1_numeric
# Out:
#      Ozone  Solar  Wind  Temp
# 0     41.0  190.0   7.4    67
# 1     36.0  118.0   8.0    72
# 2     12.0  149.0  12.6    74
# 3     18.0  313.0  11.5    62
# 4     31.0    NaN  14.3    56
# ..     ...    ...   ...   ...
# 152   20.0  223.0  11.5    68
# 153   41.0  190.0   7.4    67
# 154   30.0  193.0   6.9    70
# 155   31.0  145.0  13.2    77
# 157   18.0  131.0   8.0    76
#
# [157 rows x 4 columns]

# %%
data1.head()
# Out:
#    Ozone  Solar  Wind Month  Day  Year  Temp Weather
# 0   41.0  190.0   7.4     5    1  2010    67       S
# 1   36.0  118.0   8.0     5    2  2010    72       C
# 2   12.0  149.0  12.6     5    3  2010    74      PS
# 3   18.0  313.0  11.5     5    4  2010    62       S
# 4   31.0    NaN  14.3     5    5  2010    56       S

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 157 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    157 non-null    float64
#  1   Solar    150 non-null    float64
#  2   Wind     157 non-null    float64
#  3   Month    157 non-null    object
#  4   Day      157 non-null    int64
#  5   Year     157 non-null    int64
#  6   Temp     157 non-null    int64
#  7   Weather  157 non-null    object
# dtypes: float64(3), int64(3), object(2)
# memory usage: 11.0+ KB

# %%
#read all numeric (float) columns into a new table data1_numeric
data1_numeric = data1.iloc[:,[0,1,2,6]]
data1_numeric
# Out:
#      Ozone  Solar  Wind  Temp
# 0     41.0  190.0   7.4    67
# 1     36.0  118.0   8.0    72
# 2     12.0  149.0  12.6    74
# 3     18.0  313.0  11.5    62
# 4     31.0    NaN  14.3    56
# ..     ...    ...   ...   ...
# 152   20.0  223.0  11.5    68
# 153   41.0  190.0   7.4    67
# 154   30.0  193.0   6.9    70
# 155   31.0  145.0  13.2    77
# 157   18.0  131.0   8.0    76
#
# [157 rows x 4 columns]

# %%
#print correlation coefficinets for all the above columns
data1_numeric.corr()
# Out:
#           Ozone     Solar      Wind      Temp
# Ozone  1.000000  0.301821 -0.523738  0.597087
# Solar  0.301821  1.000000 -0.057407  0.273558
# Wind  -0.523738 -0.057407  1.000000 -0.441228
# Temp   0.597087  0.273558 -0.441228  1.000000

# %% [markdown]
# #observation
# 1.the hightest correlation is observed between the ozone and temp(0.597087)
# 2.the next higher correlation strength is obserevd between ozone and wind(-0.523738)
# 3.the next higher correlation strength is observed between wind and temperature(-0.441228)
# 4.the leastest correlation stenght is observed between the solar and wind(-0.055874)

# %%
#plot a pair plot between all numeric columns using seaborm
sns.pairplot(data1_numeric)

# %% [markdown]
# ##Transformations
# 1.categorical vraiables have to be converted to numerical using a method called one-hot encoding

# %%
#creating dummy variable for weather column
data2 = pd.get_dummies(data1,columns=['Weather','Month'])
data2
# Out:
#      Ozone  Solar  Wind  Day  Year  Temp  Weather_C  Weather_PS  Weather_S  \
# 0     41.0  190.0   7.4    1  2010    67      False       False       True
# 1     36.0  118.0   8.0    2  2010    72       True       False      False
# 2     12.0  149.0  12.6    3  2010    74      False        True      False
# 3     18.0  313.0  11.5    4  2010    62      False       False       True
# 4     31.0    NaN  14.3    5  2010    56      False       False       True
# ..     ...    ...   ...  ...   ...   ...        ...         ...        ...
# 152   20.0  223.0  11.5   30  2010    68      False       False       True
# 153   41.0  190.0   7.4    1  2010    67       True       False      False
# 154   30.0  193.0   6.9   26  2010    70      False        True      False
# 155   31.0  145.0  13.2   27  2010    77      False       False       True
# 157   18.0  131.0   8.0   29  2010    76       True       False      False
#
#      Month_5  Month_6  Month_7  Month_8  Month_9  Month_May
# ...

# %%
data1_numeric.values
# Out:
# array([[ 41. , 190. ,   7.4,  67. ],
#        [ 36. , 118. ,   8. ,  72. ],
#        [ 12. , 149. ,  12.6,  74. ],
#        [ 18. , 313. ,  11.5,  62. ],
#        [ 31. ,   nan,  14.3,  56. ],
#        [ 28. ,   nan,  14.9,  66. ],
#        [ 23. , 299. ,   8.6,  65. ],
#        [ 19. ,  99. ,  13.8,  59. ],
#        [  8. ,  19. ,  20.1,  61. ],
#        [ 31. , 194. ,   8.6,  69. ],
#        [  7. ,   nan,   6.9,  74. ],
#        [ 16. , 256. ,   9.7,  69. ],
#        [ 11. , 290. ,   9.2,  66. ],
#        [ 14. , 274. ,  10.9,  68. ],
#        [ 18. ,  65. ,  13.2,  58. ],
#        [ 14. , 334. ,  11.5,  64. ],
#        [ 34. , 307. ,  12. ,  66. ],
#        [  6. ,  78. ,  18.4,  57. ],
#        [ 30. , 322. ,  11.5,  68. ],
#        [ 11. ,  44. ,   9.7,  62. ],
#        [  1. ,   8. ,   9.7,  59. ],
#        [ 11. , 320. ,  16.6,  73. ],
#        [  4. ,  25. ,   9.7,  61. ],
#        [ 32. ,  92. ,  12. ,  61. ],
#        [ 31. ,  66. ,  16.6,  57. ],
# ...

# %%
#normalization of the data
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler

array = data1_numeric.values

scaler = MinMaxScaler(feature_range=(0,1))
rescaledX = scaler.fit_transform(array)
#transformed data
set_printoptions(precision=2)
print(rescaledX[0:10,:])
# Out:
# [[0.24 0.56 0.3  0.27]
#  [0.21 0.34 0.33 0.39]
#  [0.07 0.43 0.57 0.44]
#  [0.1  0.94 0.52 0.15]
#  [0.18  nan 0.66 0.  ]
#  [0.16  nan 0.69 0.24]
#  [0.13 0.89 0.36 0.22]
#  [0.11 0.28 0.64 0.07]
#  [0.04 0.04 0.97 0.12]
#  [0.18 0.57 0.36 0.32]]
